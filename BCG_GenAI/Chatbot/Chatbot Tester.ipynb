# %% [markdown]
# # BCG GenAI - Part 2 Chatbot Testing

# %%
import pandas as pd

# %%
data = pd.read_csv('final_data.csv')
summary = pd.read_csv('summary_final_data.csv')

# %%
# %run chatbot.py
# Out:
# Enter 'start' to start the chatbot, 'exit' to quit : start
#
# Welcome, This is the financial Chatbot
#
# Which company do you want to look at?
# Your options are:
# 1. Apple
# 2. Tesla
# 3. Microsoft
#
# Enter a company name from the options above: apple
#
# Choose data from the following financial years:
# 1. 2021
# 2. 2022
# 3. 2023
# Enter the financial year: 2203
# Enter a valid year! and start again.
# -------------------------------------------------------
#
# Enter 'start' to start the chatbot, 'exit' to quit : start
#
# Welcome, This is the financial Chatbot
#
# Which company do you want to look at?
# Your options are:
# 1. Apple
# 2. Tesla
# 3. Microsoft
#
# Enter a company name from the options above: apple
#
# Choose data from the following financial years:
# 1. 2021
# 2. 2022
# 3. 2023
# Enter the financial year: 2021
#
#
# Enter your query here: What is the total revenue?
# The total revenue (in millions) for Apple for the year 2021 is $365817.
# ...

# %%
# %run chatbot.py
# Out:
# Enter 'start' to start the chatbot, 'exit' to quit : start
#
# Welcome, This is the financial Chatbot
#
# Which company do you want to look at?
# Your options are:
# 1. Apple
# 2. Tesla
# 3. Microsoft
#
# Enter a company name from the options above: apple
#
# Choose data from the following financial years:
# 1. 2021
# 2. 2022
# 3. 2023
# Enter the financial year: 2022
#
#
# Enter your query here: sood
# Sorry, I can only provide information on predefined queries.
# -------------------------------------------------------
#
# Enter 'start' to start the chatbot, 'exit' to quit : start
#
# Welcome, This is the financial Chatbot
#
# Which company do you want to look at?
# Your options are:
# 1. Apple
# 2. Tesla
# 3. Microsoft
#
# Enter a company name from the options above: Apple
#
# Choose data from the following financial years:
# 1. 2021
# 2. 2022
# 3. 2023
# Enter the financial year: 2023
#
#
# Enter your query here: What is the value of the total assets?
# ...
